# %%
import numpy as np

# %%
import re
import string
from unicodedata import normalize
def clean(lines):
    cleaned = list()
    # prepare regex for char filtering
    re_print = re.compile('[^%s]' % re.escape(string.printable))
    # prepare translation table for removing punctuation
    table = str.maketrans('', '', string.punctuation)
    for line in lines:
        # normalize unicode characters
        line = normalize('NFD', line).encode('ascii', 'ignore')
        line = line.decode('UTF-8')
        # tokenize on white space
        line = line.split()
        # convert to lowercase
        line = [word.lower() for word in line]
        # remove punctuation from each token
        line = [word.translate(table) for word in line]
        # remove non-printable chars form each token
        line = [re_print.sub('', w) for w in line]
        # remove tokens with numbers in them
        line = [word for word in line if word.isalpha()]
        # store as string
        cleaned.append(line)
    return cleaned

# %%
import glob
documentsV=[]
documentsR=[]
with open('fra.txt',encoding="utf8") as f:
    for line in f:
        data=line.split("\t")
        documentsV.append(data[0])
        documentsR.append(data[1])
documentsV=clean(documentsV)
documentsR=clean(documentsR)

# %%
from keras.preprocessing.text import Tokenizer
tokenizerV = Tokenizer(filters=' ')
tokenizerV.fit_on_texts(documentsV)
# Out:
# Using TensorFlow backend.

# %%
tokenizerR = Tokenizer(filters=' ')
tokenizerR.fit_on_texts(documentsR)

# %%
def max_length(docs):
    return max(len(d) for d in docs)

# %%
rlength = max_length(documentsR)
vlength = max_length(documentsV)
r_vocab_size = len(tokenizerR.word_index) + 1
v_vocab_size = len(tokenizerV.word_index) + 1

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
    # integer encode sequences
    X = tokenizer.texts_to_sequences(lines)
    # pad sequences with 0 values
    X = pad_sequences(X, maxlen=length, padding='post')
    return X

# %%
from numpy import array

# one hot encode target sequence
def encode_output(sequences, vocab_size):
    ylist = list()
    for sequence in sequences:
        encoded = to_categorical(sequence, num_classes=vocab_size)
        ylist.append(encoded)
    y = array(ylist)
    y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
    return y

# %%
# prepare training data
trainX = encode_sequences(tokenizerV, vlength, documentsV)
trainY = encode_sequences(tokenizerR, rlength, documentsR)
trainY = encode_output(trainY, r_vocab_size)

# %%
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
    model = Sequential()
    model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
    model.add(LSTM(n_units))
    model.add(RepeatVector(tar_timesteps))
    model.add(LSTM(n_units, return_sequences=True))
    model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
    return model
# define model
model = define_model(v_vocab_size, r_vocab_size, vlength, rlength, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 3, 256)            82176
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 7, 256)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 7, 256)            525312
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 7, 684)            175788
# =================================================================
# Total params: 1,308,588
# Trainable params: 1,308,588
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(trainX, trainY, epochs=20, batch_size=25)
# Out:
# Epoch 1/20
# 840/840 [==============================] - 3s 4ms/step - loss: 1.1697
# Epoch 2/20
# 840/840 [==============================] - 3s 4ms/step - loss: 1.1315
# Epoch 3/20
# 840/840 [==============================] - 3s 4ms/step - loss: 1.0819
# Epoch 4/20
# 840/840 [==============================] - 3s 4ms/step - loss: 1.0399
# Epoch 5/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.9929
# Epoch 6/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.9527
# Epoch 7/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.9088
# Epoch 8/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.8687
# Epoch 9/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.8279
# Epoch 10/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.7992
# Epoch 11/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.7652
# Epoch 12/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.7340
# Epoch 13/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.7062
# Epoch 14/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.6736
# Epoch 15/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.6387
# Epoch 16/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.6145
# Epoch 17/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.5891
# Epoch 18/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.5659
# Epoch 19/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.5482
# Epoch 20/20
# 840/840 [==============================] - 3s 4ms/step - loss: 0.5269

# %%
# map an integer to a word
def word_for_id(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# %%
# generate target given source sequence
def predict_sequence(model, tokenizer, source):
    prediction = model.predict(source, verbose=0)[0]
    integers = [argmax(vector) for vector in prediction]
    target = list()
    for i in integers:
        word = word_for_id(i, tokenizer)
        if word is None:
            break
        target.append(word)
    return ' '.join(target)

# %%
from numpy import argmax
def evaluate_model(model, tokenizer, sources, raw_src, raw_target):
    actual, predicted = list(), list()
    for i, source in enumerate(sources):
        # translate encoded source text
        source = source.reshape((1, source.shape[0]))
        translation = predict_sequence(model, tokenizer, source)
        #raw_target, raw_src = raw_dataset[i]
        print('src=[%s], target=[%s], predicted=[%s]' % (raw_src[i], raw_target[i], translation))

# %%
evaluate_model(model, tokenizerR, trainX, documentsV, documentsR)
# Out:
# src=[['go']], target=[['va']], predicted=[detendstoi]
# src=[['run']], target=[['cours']], predicted=[fantastique]
# src=[['run']], target=[['courez']], predicted=[fantastique]
# src=[['fire']], target=[['au', 'feu']], predicted=[a a]
# src=[['help']], target=[['a', 'laide']], predicted=[repondezmoi]
# src=[['jump']], target=[['saute']], predicted=[genial]
# src=[['stop']], target=[['ca', 'suffit']], predicted=[stop]
# src=[['stop']], target=[['stop']], predicted=[stop]
# src=[['stop']], target=[['arretetoi']], predicted=[stop]
# src=[['wait']], target=[['attends']], predicted=[attendez]
# src=[['wait']], target=[['attendez']], predicted=[attendez]
# src=[['go', 'on']], target=[['poursuis']], predicted=[poursuis]
# src=[['go', 'on']], target=[['continuez']], predicted=[poursuis]
# src=[['go', 'on']], target=[['poursuivez']], predicted=[poursuis]
# src=[['i', 'see']], target=[['je', 'comprends']], predicted=[je comprends]
# src=[['i', 'try']], target=[['jessaye']], predicted=[je]
# src=[['i', 'won']], target=[['jai', 'gagne']], predicted=[je lai]
# src=[['i', 'won']], target=[['je', 'lai', 'emporte']], predicted=[je lai]
# src=[['oh', 'no']], target=[['oh', 'non']], predicted=[jai non]
# src=[['attack']], target=[['attaque']], predicted=[attaquez]
# src=[['attack']], target=[['attaquez']], predicted=[attaquez]
# src=[['cheers']], target=[['sante']], predicted=[merci]
# src=[['cheers']], target=[['a', 'votre', 'sante']], predicted=[merci]
# src=[['cheers']], target=[['merci']], predicted=[merci]
# src=[['cheers']], target=[['tchintchin']], predicted=[merci]
# src=[['get', 'up']], target=[['levetoi']], predicted=[levetoi]
# src=[['go', 'now']], target=[['va', 'maintenant']], predicted=[va maintenant]
# src=[['go', 'now']], target=[['allezy', 'maintenant']], predicted=[va maintenant]
# src=[['go', 'now']], target=[['vasy', 'maintenant']], predicted=[va maintenant]
# src=[['got', 'it']], target=[['jai', 'pige']], predicted=[compris]
# src=[['got', 'it']], target=[['compris']], predicted=[compris]
# src=[['got', 'it']], target=[['pige']], predicted=[compris]
# src=[['got', 'it']], target=[['compris']], predicted=[compris]
# src=[['got', 'it']], target=[['tas', 'capte']], predicted=[compris]
# src=[['hop', 'in']], target=[['monte']], predicted=[montez]
# src=[['hop', 'in']], target=[['montez']], predicted=[montez]
# src=[['hug', 'me']], target=[['serremoi', 'dans', 'tes', 'bras']], predicted=[serrezmoi dans vos bras]
# src=[['hug', 'me']], target=[['serrezmoi', 'dans', 'vos', 'bras']], predicted=[serrezmoi dans vos bras]
# src=[['i', 'fell']], target=[['je', 'suis', 'tombee']], predicted=[je suis tombe]
# src=[['i', 'fell']], target=[['je', 'suis', 'tombe']], predicted=[je suis tombe]
# src=[['i', 'know']], target=[['je', 'sais']], predicted=[je sais]
# src=[['i', 'left']], target=[['je', 'suis', 'parti']], predicted=[je suis partie]
# src=[['i', 'left']], target=[['je', 'suis', 'partie']], predicted=[je suis partie]
# src=[['i', 'lost']], target=[['jai', 'perdu']], predicted=[jai perdu]
# src=[['im']], target=[['jai', 'ans']], predicted=[je]
# src=[['im', 'ok']], target=[['je', 'vais', 'bien']], predicted=[je vais bien]
# src=[['im', 'ok']], target=[['ca', 'va']], predicted=[je vais bien]
# src=[['listen']], target=[['ecoutez']], predicted=[fantastique]
# src=[['no', 'way']], target=[['cest', 'pas', 'possible']], predicted=[tom de]
# src=[['no', 'way']], target=[['impossible']], predicted=[tom de]
# src=[['no', 'way']], target=[['en', 'aucun', 'cas']], predicted=[tom de]
# src=[['no', 'way']], target=[['sans', 'facons']], predicted=[tom de]
# src=[['no', 'way']], target=[['cest', 'hors', 'de', 'question']], predicted=[tom de]
# src=[['no', 'way']], target=[['il', 'nen', 'est', 'pas', 'question']], predicted=[tom de]
# src=[['no', 'way']], target=[['cest', 'exclu']], predicted=[tom de]
# src=[['no', 'way']], target=[['en', 'aucune', 'maniere']], predicted=[tom de]
# src=[['no', 'way']], target=[['hors', 'de', 'question']], predicted=[tom de]
# src=[['really']], target=[['vraiment']], predicted=[vraiment]
# src=[['really']], target=[['vrai']], predicted=[vraiment]
# src=[['really']], target=[['ah', 'bon']], predicted=[vraiment]
# src=[['thanks']], target=[['merci']], predicted=[merci]
# src=[['we', 'try']], target=[['on', 'essaye']], predicted=[nous essaye]
# src=[['we', 'won']], target=[['nous', 'avons', 'gagne']], predicted=[nous avons]
# src=[['we', 'won']], target=[['nous', 'gagnames']], predicted=[nous avons]
# src=[['we', 'won']], target=[['nous', 'lavons', 'emporte']], predicted=[nous avons]
# src=[['we', 'won']], target=[['nous', 'lemportames']], predicted=[nous avons]
# src=[['ask', 'tom']], target=[['demande', 'a', 'tom']], predicted=[tom a tom]
# src=[['awesome']], target=[['fantastique']], predicted=[fantastique]
# src=[['be', 'calm']], target=[['sois', 'calme']], predicted=[soyez calme]
# src=[['be', 'calm']], target=[['soyez', 'calme']], predicted=[soyez calme]
# src=[['be', 'calm']], target=[['soyez', 'calmes']], predicted=[soyez calme]
# src=[['be', 'cool']], target=[['sois', 'detendu']], predicted=[soyez calme]
# src=[['be', 'fair']], target=[['sois', 'juste']], predicted=[soyez equitable]
# src=[['be', 'fair']], target=[['soyez', 'juste']], predicted=[soyez equitable]
# src=[['be', 'fair']], target=[['soyez', 'justes']], predicted=[soyez equitable]
# src=[['be', 'fair']], target=[['sois', 'equitable']], predicted=[soyez equitable]
# src=[['be', 'fair']], target=[['soyez', 'equitable']], predicted=[soyez equitable]
# src=[['be', 'fair']], target=[['soyez', 'equitables']], predicted=[soyez equitable]
# src=[['be', 'kind']], target=[['sois', 'gentil']], predicted=[soyez gentil]
# src=[['be', 'nice']], target=[['sois', 'gentil']], predicted=[soyez gentil]
# src=[['be', 'nice']], target=[['sois', 'gentille']], predicted=[soyez gentil]
# src=[['be', 'nice']], target=[['soyez', 'gentil']], predicted=[soyez gentil]
# src=[['be', 'nice']], target=[['soyez', 'gentille']], predicted=[soyez gentil]
# src=[['be', 'nice']], target=[['soyez', 'gentils']], predicted=[soyez gentil]
# src=[['be', 'nice']], target=[['soyez', 'gentilles']], predicted=[soyez gentil]
# src=[['beat', 'it']], target=[['degage']], predicted=[degage]
# src=[['call', 'me']], target=[['appellemoi']], predicted=[appellemoi]
# src=[['call', 'me']], target=[['appellezmoi']], predicted=[appellemoi]
# src=[['call', 'us']], target=[['appellenous']], predicted=[appeleznous]
# src=[['call', 'us']], target=[['appeleznous']], predicted=[appeleznous]
# src=[['come', 'in']], target=[['entrez']], predicted=[entrez]
# src=[['come', 'in']], target=[['entre']], predicted=[entrez]
# src=[['come', 'in']], target=[['entre']], predicted=[entrez]
# src=[['come', 'in']], target=[['entrez']], predicted=[entrez]
# src=[['come', 'on']], target=[['allez']], predicted=[allez]
# src=[['come', 'on']], target=[['allez']], predicted=[allez]
# src=[['come', 'on']], target=[['viens']], predicted=[allez]
# src=[['come', 'on']], target=[['venez']], predicted=[allez]
# src=[['drop', 'it']], target=[['laisse', 'tomber']], predicted=[laissez tomber]
# src=[['drop', 'it']], target=[['laissez', 'tomber']], predicted=[laissez tomber]
# src=[['drop', 'it']], target=[['laissele', 'tomber']], predicted=[laissez tomber]
# src=[['drop', 'it']], target=[['laissezle', 'tomber']], predicted=[laissez tomber]
# src=[['get', 'out']], target=[['sortez']], predicted=[sors]
# src=[['get', 'out']], target=[['sors']], predicted=[sors]
# src=[['get', 'out']], target=[['sortez']], predicted=[sors]
# src=[['get', 'out']], target=[['sors']], predicted=[sors]
# src=[['get', 'out']], target=[['cassetoi']], predicted=[sors]
# src=[['go', 'away']], target=[['degage']], predicted=[va]
# src=[['go', 'away']], target=[['pars']], predicted=[va]
# src=[['go', 'away']], target=[['va', 'te', 'faire', 'foutre']], predicted=[va]
# src=[['go', 'away']], target=[['pars']], predicted=[va]
# src=[['go', 'away']], target=[['degage']], predicted=[va]
# src=[['go', 'away']], target=[['fous', 'le', 'camp']], predicted=[va]
# src=[['go', 'away']], target=[['pars', 'dici']], predicted=[va]
# src=[['go', 'away']], target=[['va', 'ten']], predicted=[va]
# src=[['go', 'away']], target=[['disparais']], predicted=[va]
# src=[['go', 'away']], target=[['allezvous', 'en']], predicted=[va]
# src=[['go', 'slow']], target=[['va', 'doucement']], predicted=[va doucement]
# src=[['go', 'slow']], target=[['allez', 'doucement']], predicted=[va doucement]
# src=[['goodbye']], target=[['a', 'la', 'revoyure']], predicted=[qui est revoyure]
# src=[['hang', 'on']], target=[['attends', 'un', 'peu']], predicted=[attends un]
# src=[['hang', 'on']], target=[['attendez', 'un', 'peu']], predicted=[attends un]
# src=[['hang', 'on']], target=[['tiens', 'bon']], predicted=[attends un]
# src=[['hang', 'on']], target=[['tenez', 'bon']], predicted=[attends un]
# src=[['he', 'quit']], target=[['il', 'laissa', 'tomber']], predicted=[il laissa tomber]
# src=[['he', 'quit']], target=[['il', 'a', 'laisse', 'tomber']], predicted=[il laissa tomber]
# src=[['he', 'runs']], target=[['il', 'court']], predicted=[il court]
# src=[['help', 'me']], target=[['aidemoi']], predicted=[aidemoi]
# src=[['help', 'me']], target=[['aidemoi']], predicted=[aidemoi]
# src=[['help', 'me']], target=[['aidezmoi']], predicted=[aidemoi]
# src=[['help', 'us']], target=[['aideznous']], predicted=[aideznous]
# src=[['help', 'us']], target=[['aidenous']], predicted=[aideznous]
# src=[['hold', 'it']], target=[['ne', 'bouge', 'plus']], predicted=[ne bouge plus]
# src=[['hold', 'on']], target=[['ne', 'quittez', 'pas']], predicted=[ne quittez pas]
# src=[['hug', 'tom']], target=[['fais', 'un', 'calin', 'a', 'tom']], predicted=[comment oiseaux calin]
# src=[['i', 'agree']], target=[['je', 'suis', 'du', 'meme', 'avis']], predicted=[je suis en meme]
# src=[['i', 'drive']], target=[['je', 'conduis']], predicted=[je conduis]
# src=[['i', 'tried']], target=[['jessayai']], predicted=[jai]
# src=[['i', 'tried']], target=[['jai', 'essaye']], predicted=[jai]
# src=[['i', 'tried']], target=[['jai', 'tente']], predicted=[jai]
# src=[['ill', 'go']], target=[['jirai']], predicted=[jirai]
# src=[['im', 'fat']], target=[['je', 'suis', 'gras']], predicted=[je suis pret]
# src=[['im', 'fat']], target=[['je', 'suis', 'gros']], predicted=[je suis pret]
# src=[['im', 'fit']], target=[['je', 'suis', 'en', 'forme']], predicted=[je suis en]
# src=[['im', 'hit']], target=[['je', 'suis', 'touche']], predicted=[je suis]
# src=[['im', 'hit']], target=[['je', 'suis', 'touchee']], predicted=[je suis]
# src=[['im', 'ill']], target=[['je', 'suis', 'malade']], predicted=[je suis malade]
# src=[['im', 'sad']], target=[['je', 'suis', 'triste']], predicted=[je suis]
# src=[['im', 'shy']], target=[['je', 'suis', 'timide']], predicted=[je suis timide]
# src=[['im', 'wet']], target=[['je', 'suis', 'mouille']], predicted=[je suis timide]
# src=[['im', 'wet']], target=[['je', 'suis', 'mouillee']], predicted=[je suis timide]
# src=[['its', 'me']], target=[['cest', 'bibi']], predicted=[cest gratuit]
# src=[['join', 'us']], target=[['joignezvous']], predicted=[joignezvous]
# src=[['join', 'us']], target=[['joignezvous', 'a', 'nous']], predicted=[joignezvous]
# src=[['keep', 'it']], target=[['gardele']], predicted=[gardele]
# src=[['keep', 'it']], target=[['gardezle']], predicted=[gardele]
# src=[['kiss', 'me']], target=[['embrassemoi']], predicted=[embrassezmoi]
# src=[['kiss', 'me']], target=[['embrassezmoi']], predicted=[embrassezmoi]
# src=[['me', 'too']], target=[['moi', 'aussi']], predicted=[va]
# src=[['open', 'up']], target=[['ouvremoi']], predicted=[ouvremoi]
# src=[['open', 'up']], target=[['ouvre']], predicted=[ouvremoi]
# src=[['perfect']], target=[['parfait']], predicted=[genial]
# src=[['see', 'you']], target=[['a', 'plus']], predicted=[a plus]
# src=[['show', 'me']], target=[['montremoi']], predicted=[montrezmoi]
# src=[['show', 'me']], target=[['montrezmoi']], predicted=[montrezmoi]
# src=[['shut', 'up']], target=[['taisezvous']], predicted=[fermela]
# src=[['shut', 'up']], target=[['fermela']], predicted=[fermela]
# src=[['shut', 'up']], target=[['taistoi']], predicted=[fermela]
# src=[['shut', 'up']], target=[['fermela']], predicted=[fermela]
# src=[['shut', 'up']], target=[['la', 'ferme']], predicted=[fermela]
# src=[['so', 'long']], target=[['a', 'plus', 'tard']], predicted=[tom plus]
# src=[['take', 'it']], target=[['prendsle']], predicted=[prendsle]
# src=[['take', 'it']], target=[['prenezle']], predicted=[prendsle]
# src=[['tell', 'me']], target=[['dismoi']], predicted=[dismoi]
# src=[['tell', 'me']], target=[['ditesmoi']], predicted=[dismoi]
# src=[['tom', 'won']], target=[['tom', 'a', 'gagne']], predicted=[tom a gagne]
# src=[['wake', 'up']], target=[['reveilletoi']], predicted=[reveilletoi]
# src=[['wake', 'up']], target=[['reveilletoi']], predicted=[reveilletoi]
# src=[['wake', 'up']], target=[['reveillezvous']], predicted=[reveilletoi]
# src=[['wake', 'up']], target=[['reveilletoi']], predicted=[reveilletoi]
# src=[['wake', 'up']], target=[['reveillezvous']], predicted=[reveilletoi]
# src=[['wash', 'up']], target=[['lavetoi']], predicted=[lavezvous]
# src=[['wash', 'up']], target=[['lavezvous']], predicted=[lavezvous]
# src=[['we', 'know']], target=[['nous', 'savons']], predicted=[nous savons]
# src=[['we', 'lost']], target=[['nous', 'perdimes']], predicted=[nous fumes ete]
# src=[['we', 'lost']], target=[['nous', 'avons', 'perdu']], predicted=[nous fumes ete]
# src=[['we', 'lost']], target=[['nous', 'fumes', 'battus']], predicted=[nous fumes ete]
# src=[['we', 'lost']], target=[['nous', 'fumes', 'battues']], predicted=[nous fumes ete]
# src=[['we', 'lost']], target=[['nous', 'fumes', 'defaits']], predicted=[nous fumes ete]
# src=[['we', 'lost']], target=[['nous', 'fumes', 'defaites']], predicted=[nous fumes ete]
# src=[['we', 'lost']], target=[['nous', 'avons', 'ete', 'defaits']], predicted=[nous fumes ete]
# src=[['we', 'lost']], target=[['nous', 'avons', 'ete', 'defaites']], predicted=[nous fumes ete]
# src=[['we', 'lost']], target=[['nous', 'avons', 'ete', 'battus']], predicted=[nous fumes ete]
# src=[['we', 'lost']], target=[['nous', 'avons', 'ete', 'battues']], predicted=[nous fumes ete]
# src=[['who', 'won']], target=[['qui', 'a', 'gagne']], predicted=[nous est]
# src=[['who', 'won']], target=[['qui', 'la', 'emporte']], predicted=[nous est]
# src=[['you', 'run']], target=[['tu', 'cours']], predicted=[tu cours]
# src=[['am', 'i', 'fat']], target=[['suisje', 'gros']], predicted=[suisje grosse]
# src=[['am', 'i', 'fat']], target=[['suisje', 'grosse']], predicted=[suisje grosse]
# src=[['ask', 'them']], target=[['demandeleur']], predicted=[demandeleur]
# src=[['ask', 'them']], target=[['demandezleur']], predicted=[demandeleur]
# src=[['back', 'off']], target=[['recule']], predicted=[reculez]
# src=[['back', 'off']], target=[['reculez']], predicted=[reculez]
# src=[['back', 'off']], target=[['recule']], predicted=[reculez]
# src=[['back', 'off']], target=[['reculez']], predicted=[reculez]
# src=[['back', 'off']], target=[['retiretoi']], predicted=[reculez]
# src=[['back', 'off']], target=[['retirezvous']], predicted=[reculez]
# src=[['be', 'a', 'man']], target=[['sois', 'un', 'homme']], predicted=[soyez un homme]
# src=[['be', 'a', 'man']], target=[['soyez', 'un', 'homme']], predicted=[soyez un homme]
# src=[['be', 'still']], target=[['sois', 'calme']], predicted=[soyez calme]
# src=[['be', 'still']], target=[['soyez', 'calme']], predicted=[soyez calme]
# src=[['be', 'still']], target=[['soyez', 'calmes']], predicted=[soyez calme]
# src=[['beats', 'me']], target=[['aucune', 'idee']], predicted=[nous idee]
# src=[['beats', 'me']], target=[['jen', 'sais', 'foutre', 'rien']], predicted=[nous idee]
# src=[['call', 'tom']], target=[['appelle', 'tom']], predicted=[appelle tom]
# src=[['call', 'tom']], target=[['appelez', 'tom']], predicted=[appelle tom]
# src=[['cheer', 'up']], target=[['courage']], predicted=[lavezvous]
# src=[['cool', 'off']], target=[['detendstoi']], predicted=[detendstoi]
# src=[['cuff', 'him']], target=[['menottezle']], predicted=[menottezle]
# src=[['drive', 'on']], target=[['avance']], predicted=[avancez]
# src=[['drive', 'on']], target=[['avancez']], predicted=[avancez]
# src=[['drive', 'on']], target=[['continue', 'a', 'rouler']], predicted=[avancez]
# src=[['drive', 'on']], target=[['continuez', 'a', 'rouler']], predicted=[avancez]
# src=[['find', 'tom']], target=[['trouve', 'tom']], predicted=[appelle tom]
# src=[['find', 'tom']], target=[['trouvez', 'tom']], predicted=[appelle tom]
# src=[['get', 'down']], target=[['lachetoi']], predicted=[lachetoi]
# src=[['get', 'down']], target=[['descends']], predicted=[lachetoi]
# src=[['get', 'down']], target=[['descendez']], predicted=[lachetoi]
# src=[['get', 'down']], target=[['lachetoi']], predicted=[lachetoi]
# src=[['get', 'down']], target=[['lachezvous']], predicted=[lachetoi]
# src=[['get', 'lost']], target=[['va', 'voir', 'ailleurs', 'si', 'jy', 'suis']], predicted=[va au]
# src=[['get', 'lost']], target=[['degage']], predicted=[va au]
# src=[['get', 'lost']], target=[['va', 'au', 'diable']], predicted=[va au]
# src=[['get', 'real']], target=[['sois', 'realiste']], predicted=[sois realiste]
# src=[['go', 'ahead']], target=[['vasy']], predicted=[vasy]
# src=[['go', 'ahead']], target=[['poursuis']], predicted=[vasy]
# src=[['go', 'ahead']], target=[['passe', 'devant']], predicted=[vasy]
# src=[['go', 'ahead']], target=[['vasy']], predicted=[vasy]
# src=[['good', 'job']], target=[['bien', 'joue']], predicted=[beau joue]
# src=[['good', 'job']], target=[['bon', 'boulot']], predicted=[beau joue]
# src=[['good', 'job']], target=[['beau', 'travail']], predicted=[beau joue]
# src=[['grab', 'him']], target=[['attrapele']], predicted=[attrapezle]
# src=[['grab', 'him']], target=[['attrapezle']], predicted=[attrapezle]
# src=[['have', 'fun']], target=[['amusetoi', 'bien']], predicted=[amusezvous bien]
# src=[['have', 'fun']], target=[['amusezvous', 'bien']], predicted=[amusezvous bien]
# src=[['he', 'tries']], target=[['il', 'essaye']], predicted=[il essaye]
# src=[['hes', 'wet']], target=[['il', 'est', 'mouille']], predicted=[il est mouille]
# src=[['help', 'tom']], target=[['aide', 'tom']], predicted=[aidez tom]
# src=[['help', 'tom']], target=[['aidez', 'tom']], predicted=[aidez tom]
# src=[['hi', 'guys']], target=[['salut', 'les', 'mecs']], predicted=[salut les mecs]
# src=[['how', 'cute']], target=[['comme', 'cest', 'mignon']], predicted=[comme cest mignon]
# src=[['how', 'deep']], target=[['quelle', 'profondeur']], predicted=[quelle profondeur]
# src=[['how', 'nice']], target=[['comme', 'cest', 'chouette']], predicted=[comme cest joli]
# src=[['how', 'nice']], target=[['comme', 'cest', 'gentil']], predicted=[comme cest joli]
# src=[['how', 'nice']], target=[['cest', 'du', 'joli']], predicted=[comme cest joli]
# src=[['how', 'nice']], target=[['comme', 'cest', 'agreable']], predicted=[comme cest joli]
# src=[['humor', 'me']], target=[['faismoi', 'rire']], predicted=[faismoi rire]
# src=[['hurry', 'up']], target=[['depechetoi']], predicted=[grouille]
# src=[['hurry', 'up']], target=[['grouille']], predicted=[grouille]
# src=[['hurry', 'up']], target=[['pressezvous']], predicted=[grouille]
# src=[['hurry', 'up']], target=[['fica']], predicted=[grouille]
# src=[['i', 'am', 'fat']], target=[['je', 'suis', 'gras']], predicted=[je suis gras]
# src=[['i', 'did', 'ok']], target=[['je', 'men', 'suis', 'bien', 'sorti']], predicted=[je vous suis bien]
# src=[['i', 'did', 'ok']], target=[['je', 'men', 'suis', 'bien', 'sortie']], predicted=[je vous suis bien]
# src=[['i', 'did', 'it']], target=[['je', 'lai', 'fait']], predicted=[je lai qui]
# src=[['i', 'did', 'it']], target=[['cest', 'moi', 'qui', 'lai', 'fait']], predicted=[je lai qui]
# src=[['i', 'failed']], target=[['jai', 'echoue']], predicted=[jai echoue]
# src=[['i', 'forgot']], target=[['jai', 'oublie']], predicted=[jai]
# src=[['i', 'get', 'it']], target=[['jai', 'compris']], predicted=[je compris]
# src=[['i', 'got', 'it']], target=[['jai', 'compris']], predicted=[je compris]
# src=[['i', 'got', 'it']], target=[['jai', 'capte']], predicted=[je compris]
# src=[['i', 'phoned']], target=[['je', 'telephonai']], predicted=[je telephonai]
# src=[['i', 'phoned']], target=[['jai', 'telephone']], predicted=[je telephonai]
# src=[['i', 'refuse']], target=[['je', 'refuse']], predicted=[je suis]
# src=[['i', 'refuse']], target=[['je', 'le', 'refuse']], predicted=[je suis]
# src=[['i', 'saw', 'it']], target=[['je', 'lai', 'vu']], predicted=[je lai vu]
# src=[['i', 'saw', 'it']], target=[['je', 'lai', 'vu']], predicted=[je lai vu]
# src=[['i', 'stayed']], target=[['je', 'suis', 'reste']], predicted=[je suis restee]
# src=[['i', 'stayed']], target=[['je', 'suis', 'restee']], predicted=[je suis restee]
# src=[['i', 'use', 'it']], target=[['je', 'lutilise']], predicted=[je lai]
# src=[['i', 'use', 'it']], target=[['jen', 'fais', 'usage']], predicted=[je lai]
# src=[['i', 'use', 'it']], target=[['je', 'men', 'sers']], predicted=[je lai]
# src=[['ill', 'pay']], target=[['je', 'paierai']], predicted=[je marcherai]
# src=[['ill', 'try']], target=[['je', 'vais', 'essayer']], predicted=[je]
# src=[['ill', 'try']], target=[['jessaierai']], predicted=[je]
# src=[['im', 'back']], target=[['je', 'suis', 'revenu']], predicted=[je suis]
# src=[['im', 'back']], target=[['me', 'revoila']], predicted=[je suis]
# src=[['im', 'bald']], target=[['je', 'suis', 'chauve']], predicted=[je suis libre]
# src=[['im', 'busy']], target=[['je', 'suis', 'occupe']], predicted=[je suis timide]
# src=[['im', 'busy']], target=[['je', 'suis', 'occupee']], predicted=[je suis timide]
# src=[['im', 'calm']], target=[['je', 'suis', 'calme']], predicted=[je suis calme]
# src=[['im', 'cold']], target=[['jai', 'froid']], predicted=[jai]
# src=[['im', 'deaf']], target=[['je', 'suis', 'sourd']], predicted=[je suis timide]
# src=[['im', 'deaf']], target=[['je', 'suis', 'sourde']], predicted=[je suis timide]
# src=[['im', 'done']], target=[['jen', 'ai', 'fini']], predicted=[je suis]
# src=[['im', 'fast']], target=[['je', 'suis', 'rapide']], predicted=[je suis pret]
# src=[['im', 'fine']], target=[['tout', 'va', 'bien']], predicted=[je vais bien]
# src=[['im', 'fine']], target=[['je', 'vais', 'bien']], predicted=[je vais bien]
# src=[['im', 'fine']], target=[['ca', 'va']], predicted=[je vais bien]
# src=[['im', 'free']], target=[['je', 'suis', 'libre']], predicted=[je suis libre]
# src=[['im', 'free']], target=[['je', 'suis', 'libre']], predicted=[je suis libre]
# src=[['im', 'free']], target=[['je', 'suis', 'disponible']], predicted=[je suis libre]
# src=[['im', 'full']], target=[['je', 'suis', 'repu']], predicted=[je suis timide]
# src=[['im', 'full']], target=[['je', 'suis', 'rassasie']], predicted=[je suis timide]
# src=[['im', 'glad']], target=[['je', 'suis', 'content']], predicted=[je suis timide]
# src=[['im', 'home']], target=[['je', 'suis', 'chez', 'moi']], predicted=[je suis en]
# src=[['im', 'late']], target=[['je', 'suis', 'en', 'retard']], predicted=[je suis en]
# src=[['im', 'lazy']], target=[['je', 'suis', 'paresseux']], predicted=[je suis libre]
# src=[['im', 'lazy']], target=[['je', 'suis', 'faineant']], predicted=[je suis libre]
# src=[['im', 'lazy']], target=[['je', 'suis', 'paresseuse']], predicted=[je suis libre]
# src=[['im', 'lazy']], target=[['je', 'suis', 'faineante']], predicted=[je suis libre]
# src=[['im', 'okay']], target=[['je', 'vais', 'bien']], predicted=[je vais bien]
# src=[['im', 'okay']], target=[['je', 'me', 'porte', 'bien']], predicted=[je vais bien]
# src=[['im', 'safe']], target=[['je', 'suis', 'en', 'securite']], predicted=[je suis en]
# src=[['im', 'sick']], target=[['je', 'suis', 'malade']], predicted=[je suis libre]
# src=[['im', 'sure']], target=[['jen', 'suis', 'certain']], predicted=[je suis certain]
# src=[['im', 'sure']], target=[['je', 'suis', 'certain']], predicted=[je suis certain]
# src=[['im', 'sure']], target=[['jen', 'suis', 'sur']], predicted=[je suis certain]
# src=[['im', 'sure']], target=[['jen', 'suis', 'sure']], predicted=[je suis certain]
# src=[['im', 'tall']], target=[['je', 'suis', 'grande']], predicted=[je suis faible]
# src=[['im', 'thin']], target=[['je', 'suis', 'mince']], predicted=[je suis]
# src=[['im', 'tidy']], target=[['je', 'suis', 'ordonne']], predicted=[je suis timide]
# src=[['im', 'tidy']], target=[['je', 'suis', 'ordonnee']], predicted=[je suis timide]
# src=[['im', 'ugly']], target=[['je', 'suis', 'laid']], predicted=[je suis calme]
# src=[['im', 'ugly']], target=[['je', 'suis', 'laide']], predicted=[je suis calme]
# src=[['im', 'weak']], target=[['je', 'suis', 'faible']], predicted=[je suis faible]
# src=[['im', 'well']], target=[['je', 'vais', 'bien']], predicted=[je vais bien]
# src=[['im', 'well']], target=[['je', 'me', 'porte', 'bien']], predicted=[je vais bien]
# src=[['ive', 'won']], target=[['jai', 'gagne']], predicted=[je lai]
# src=[['ive', 'won']], target=[['je', 'lai', 'emporte']], predicted=[je lai]
# src=[['it', 'helps']], target=[['ca', 'aide']], predicted=[ca aide]
# src=[['it', 'hurts']], target=[['ca', 'fait', 'mal']], predicted=[ca fait]
# src=[['it', 'works']], target=[['elle', 'marche']], predicted=[elle marche]
# src=[['it', 'works']], target=[['ca', 'fonctionne']], predicted=[elle marche]
# src=[['its', 'tom']], target=[['cest', 'tom']], predicted=[cest a]
# src=[['its', 'fun']], target=[['cest', 'marrant']], predicted=[cest rigolo]
# src=[['its', 'fun']], target=[['cest', 'rigolo']], predicted=[cest rigolo]
# src=[['its', 'his']], target=[['cest', 'le', 'sien']], predicted=[cest est]
# src=[['its', 'his']], target=[['cest', 'la', 'sienne']], predicted=[cest est]
# src=[['its', 'new']], target=[['cest', 'nouveau']], predicted=[cest neuf]
# src=[['its', 'new']], target=[['cest', 'neuf']], predicted=[cest neuf]
# src=[['its', 'odd']], target=[['cest', 'bizarre']], predicted=[cest neuf]
# src=[['its', 'sad']], target=[['cest', 'triste']], predicted=[cest triste]
# src=[['keep', 'out']], target=[['defense', 'dentrer']], predicted=[nentrez dentrer]
# src=[['keep', 'out']], target=[['nentrez', 'pas']], predicted=[nentrez dentrer]
# src=[['kiss', 'tom']], target=[['embrasse', 'tom']], predicted=[embrasse tom]
# src=[['leave', 'it']], target=[['laisse', 'tomber']], predicted=[laisse tomber]
# src=[['leave', 'it']], target=[['laissez', 'tomber']], predicted=[laisse tomber]
# src=[['leave', 'me']], target=[['laissezmoi']], predicted=[laissezmoi]
# src=[['leave', 'us']], target=[['laissenous']], predicted=[laisseznous]
# src=[['leave', 'us']], target=[['laisseznous']], predicted=[laisseznous]
# src=[['lets', 'go']], target=[['allonsy']], predicted=[allonsy]
# src=[['lets', 'go']], target=[['allons']], predicted=[allonsy]
# src=[['look', 'out']], target=[['attention']], predicted=[regarde]
# src=[['look', 'out']], target=[['regarde', 'donc']], predicted=[regarde]
# src=[['marry', 'me']], target=[['epousemoi']], predicted=[aidemoi]
# src=[['marry', 'me']], target=[['epousezmoi']], predicted=[aidemoi]
# src=[['may', 'i', 'go']], target=[['puisje', 'partir']], predicted=[puisje partir]
# src=[['may', 'i', 'go']], target=[['puisje', 'y', 'aller']], predicted=[puisje partir]
# src=[['may', 'i', 'go']], target=[['puisje', 'my', 'rendre']], predicted=[puisje partir]
# src=[['save', 'tom']], target=[['sauve', 'tom']], predicted=[embrasse tom]
# src=[['save', 'tom']], target=[['sauvez', 'tom']], predicted=[embrasse tom]
# src=[['she', 'came']], target=[['elle', 'est', 'venue']], predicted=[elle est venue]
# src=[['she', 'died']], target=[['elle', 'est', 'morte']], predicted=[elle est]
# src=[['she', 'runs']], target=[['elle', 'court']], predicted=[elle court]
# src=[['sit', 'down']], target=[['assiedstoi']], predicted=[assiedstoi]
# src=[['sit', 'down']], target=[['asseyezvous']], predicted=[assiedstoi]
# src=[['sit', 'here']], target=[['assiedstoi', 'ici']], predicted=[asseyezvous ici]
# src=[['sit', 'here']], target=[['asseyezvous', 'ici']], predicted=[asseyezvous ici]
# src=[['speak', 'up']], target=[['parle', 'plus', 'fort']], predicted=[parlez plus fort]
# src=[['speak', 'up']], target=[['parlez', 'plus', 'fort']], predicted=[parlez plus fort]
# src=[['stop', 'tom']], target=[['arrete', 'tom']], predicted=[stoppez tom]
# src=[['stop', 'tom']], target=[['stoppez', 'tom']], predicted=[stoppez tom]
# src=[['tell', 'tom']], target=[['disle', 'a', 'tom']], predicted=[informezen a tom]
# src=[['tell', 'tom']], target=[['informezen', 'tom']], predicted=[informezen a tom]
# src=[['terrific']], target=[['genial']], predicted=[genial]
# src=[['terrific']], target=[['excellent']], predicted=[genial]
# src=[['terrific']], target=[['formidable']], predicted=[genial]
# src=[['they', 'won']], target=[['ils', 'gagnerent']], predicted=[ils gagnerent]
# src=[['they', 'won']], target=[['elles', 'gagnerent']], predicted=[ils gagnerent]
# src=[['they', 'won']], target=[['ils', 'ont', 'gagne']], predicted=[ils gagnerent]
# src=[['they', 'won']], target=[['elles', 'ont', 'gagne']], predicted=[ils gagnerent]
# src=[['tom', 'came']], target=[['tom', 'est', 'venu']], predicted=[tom est]
# src=[['tom', 'died']], target=[['tom', 'est', 'mort']], predicted=[tom est]
# src=[['tom', 'died']], target=[['tom', 'muera']], predicted=[tom est]
# src=[['tom', 'knew']], target=[['tom', 'savait']], predicted=[tom savait]
# src=[['tom', 'left']], target=[['tom', 'est', 'parti']], predicted=[tom est]
# src=[['tom', 'left']], target=[['tom', 'partit']], predicted=[tom est]
# src=[['tom', 'lied']], target=[['tom', 'a', 'menti']], predicted=[tom a menti]
# src=[['tom', 'lies']], target=[['tom', 'ment']], predicted=[tom ment]
# src=[['tom', 'lost']], target=[['tom', 'a', 'perdu']], predicted=[tom a perdu]
# src=[['tom', 'paid']], target=[['tom', 'a', 'paye']], predicted=[tom a paye]
# src=[['too', 'late']], target=[['trop', 'tard']], predicted=[qui tard]
# src=[['trust', 'me']], target=[['faitesmoi', 'confiance']], predicted=[faismoi confiance]
# src=[['trust', 'me']], target=[['faismoi', 'confiance']], predicted=[faismoi confiance]
# src=[['try', 'hard']], target=[['fais', 'un', 'effort']], predicted=[fais un effort]
# src=[['try', 'some']], target=[['essaiesen']], predicted=[essaiesen]
# src=[['try', 'some']], target=[['essayezen']], predicted=[essaiesen]
# src=[['try', 'this']], target=[['essaie', 'ceci']], predicted=[essayez ceci]
# src=[['try', 'this']], target=[['essayez', 'ceci']], predicted=[essayez ceci]
# src=[['use', 'this']], target=[['utilise', 'ceci']], predicted=[utilisez ceci]
# src=[['use', 'this']], target=[['utilisez', 'ceci']], predicted=[utilisez ceci]
# src=[['use', 'this']], target=[['emploie', 'ceci']], predicted=[utilisez ceci]
# src=[['use', 'this']], target=[['employez', 'ceci']], predicted=[utilisez ceci]
# src=[['warn', 'tom']], target=[['avertis', 'tom']], predicted=[previens tom]
# src=[['warn', 'tom']], target=[['previens', 'tom']], predicted=[previens tom]
# src=[['watch', 'me']], target=[['regardemoi']], predicted=[regardezmoi]
# src=[['watch', 'me']], target=[['regardezmoi']], predicted=[regardezmoi]
# src=[['watch', 'us']], target=[['regardeznous']], predicted=[regardeznous]
# src=[['watch', 'us']], target=[['regardenous']], predicted=[regardeznous]
# src=[['we', 'agree']], target=[['nous', 'sommes', 'daccord']], predicted=[nous sommes daccord]
# src=[['well', 'go']], target=[['nous', 'irons']], predicted=[nous irons]
# src=[['what', 'for']], target=[['pour', 'quoi', 'faire']], predicted=[ne quoi bon]
# src=[['what', 'for']], target=[['a', 'quoi', 'bon']], predicted=[ne quoi bon]
# src=[['what', 'fun']], target=[['questce', 'quon', 'sest', 'marres']], predicted=[questce quon sest marres]
# src=[['what', 'fun']], target=[['questce', 'quon', 'sest', 'marrees']], predicted=[questce quon sest marres]
# src=[['who', 'came']], target=[['qui', 'est', 'venu']], predicted=[qui est tombe]
# src=[['who', 'died']], target=[['qui', 'est', 'mort']], predicted=[qui est venu]
# src=[['who', 'fell']], target=[['qui', 'est', 'tombe']], predicted=[qui est tombe]
# src=[['whos', 'he']], target=[['qui', 'estil']], predicted=[qui estil]
# src=[['write', 'me']], target=[['ecrismoi']], predicted=[ecrismoi]
# src=[['write', 'me']], target=[['ecrivezmoi']], predicted=[ecrismoi]
# src=[['you', 'lost']], target=[['tu', 'as', 'perdu']], predicted=[tu as perdu]
# src=[['you', 'lost']], target=[['vous', 'avez', 'perdu']], predicted=[tu as perdu]
# src=[['after', 'you']], target=[['apres', 'vous']], predicted=[apres vous]
# src=[['aim', 'fire']], target=[['en', 'joue', 'feu']], predicted=[questce a feu]
# src=[['am', 'i', 'late']], target=[['suisje', 'en', 'retard']], predicted=[suisje suis retard]
# src=[['answer', 'me']], target=[['repondezmoi']], predicted=[repondezmoi]
# src=[['be', 'seated']], target=[['assiedstoi']], predicted=[asseyezvous]
# src=[['be', 'seated']], target=[['asseyezvous']], predicted=[asseyezvous]
# src=[['birds', 'fly']], target=[['les', 'oiseaux', 'volent']], predicted=[les oiseaux volent]
# src=[['bless', 'you']], target=[['a', 'tes', 'souhaits']], predicted=[a a]
# src=[['call', 'home']], target=[['appelle', 'a', 'la', 'maison']], predicted=[appelle a la maison]
# src=[['calm', 'down']], target=[['calmezvous']], predicted=[calmezvous]
# src=[['calm', 'down']], target=[['calmetoi']], predicted=[calmezvous]
# src=[['can', 'we', 'go']], target=[['pouvonsnous', 'partir']], predicted=[pouvonsnous y]
# src=[['can', 'we', 'go']], target=[['pouvonsnous', 'nous', 'en', 'aller']], predicted=[pouvonsnous y]
# src=[['can', 'we', 'go']], target=[['pouvonsnous', 'y', 'aller']], predicted=[pouvonsnous y]
# src=[['catch', 'tom']], target=[['attrape', 'tom']], predicted=[attrape tom]
# src=[['catch', 'tom']], target=[['attrapez', 'tom']], predicted=[attrape tom]
# src=[['catch', 'him']], target=[['rattrapele']], predicted=[rattrapele]
# src=[['come', 'back']], target=[['reviens']], predicted=[reviens]
# src=[['come', 'back']], target=[['revenez']], predicted=[reviens]
# src=[['come', 'here']], target=[['viens', 'ici']], predicted=[venez ici]
# src=[['come', 'here']], target=[['venez', 'la']], predicted=[venez ici]
# src=[['come', 'over']], target=[['viens']], predicted=[venez chez]
# src=[['come', 'over']], target=[['venez']], predicted=[venez chez]
# src=[['come', 'over']], target=[['venez', 'ici']], predicted=[venez chez]
# src=[['come', 'over']], target=[['viens', 'chez', 'nous']], predicted=[venez chez]
# src=[['come', 'over']], target=[['venez', 'chez', 'nous']], predicted=[venez chez]
# src=[['come', 'over']], target=[['viens', 'chez', 'moi']], predicted=[venez chez]
# src=[['come', 'over']], target=[['venez', 'chez', 'moi']], predicted=[venez chez]
# src=[['come', 'soon']], target=[['viens', 'bientot']], predicted=[viens chez]
# src=[['come', 'soon']], target=[['venez', 'bientot']], predicted=[viens chez]
# src=[['cool', 'down']], target=[['calmezvous']], predicted=[calmezvous]
# src=[['did', 'i', 'win']], target=[['aije', 'gagne']], predicted=[laije moi]
# src=[['did', 'i', 'win']], target=[['laije', 'emporte']], predicted=[laije moi]
# src=[['did', 'i', 'win']], target=[['estce', 'moi', 'qui', 'ai', 'gagne']], predicted=[laije moi]
# src=[['do', 'it', 'now']], target=[['faitesle', 'maintenant']], predicted=[faitesle maintenant]
# src=[['dogs', 'bark']], target=[['des', 'chiens', 'aboient']], predicted=[des chiens aboient]
# src=[['dogs', 'bark']], target=[['les', 'chiens', 'aboient']], predicted=[des chiens aboient]
# src=[['dont', 'ask']], target=[['ne', 'demande', 'pas']], predicted=[ne demande pas]
# src=[['dont', 'cry']], target=[['ne', 'pleure', 'pas']], predicted=[ne mourez pas]
# src=[['dont', 'die']], target=[['ne', 'meurs', 'pas']], predicted=[ne mourez pas]
# src=[['dont', 'die']], target=[['ne', 'mourez', 'pas']], predicted=[ne mourez pas]
# src=[['dont', 'lie']], target=[['ne', 'mens', 'pas']], predicted=[ne mens pas]
# src=[['dont', 'run']], target=[['ne', 'courez', 'pas']], predicted=[ne cours pas]
# src=[['dont', 'run']], target=[['ne', 'cours', 'pas']], predicted=[ne cours pas]
# src=[['excuse', 'me']], target=[['excusemoi']], predicted=[excusemoi]
# src=[['fantastic']], target=[['fantastique']], predicted=[fantastique]
# src=[['feel', 'this']], target=[['sens', 'ca']], predicted=[sentez ca]
# src=[['feel', 'this']], target=[['sentez', 'ca']], predicted=[sentez ca]
# src=[['feel', 'this']], target=[['touche', 'ca']], predicted=[sentez ca]
# src=[['feel', 'this']], target=[['touchez', 'ca']], predicted=[sentez ca]
# src=[['follow', 'me']], target=[['suismoi']], predicted=[regardezmoi]
# src=[['follow', 'us']], target=[['suisnous']], predicted=[regardeznous]
# src=[['follow', 'us']], target=[['suiveznous']], predicted=[regardeznous]
# src=[['forget', 'it']], target=[['oublie']], predicted=[oublie]
# src=[['forget', 'it']], target=[['oubliele']], predicted=[oublie]
# src=[['forget', 'it']], target=[['oubliez']], predicted=[oublie]
# src=[['forget', 'it']], target=[['oubliezle']], predicted=[oublie]
# src=[['forget', 'it']], target=[['laisse', 'tomber']], predicted=[oublie]
# src=[['forget', 'it']], target=[['oublie']], predicted=[oublie]
# src=[['get', 'a', 'job']], target=[['trouve', 'un', 'emploi']], predicted=[trouvez un emploi]
# src=[['get', 'a', 'job']], target=[['trouve', 'un', 'boulot']], predicted=[trouvez un emploi]
# src=[['get', 'a', 'job']], target=[['trouvez', 'un', 'emploi']], predicted=[trouvez un emploi]
# src=[['get', 'a', 'job']], target=[['trouvez', 'un', 'boulot']], predicted=[trouvez un emploi]
# src=[['get', 'ready']], target=[['preparetoi']], predicted=[preparezvous]
# src=[['get', 'ready']], target=[['preparezvous']], predicted=[preparezvous]
# src=[['go', 'get', 'it']], target=[['va', 'le', 'chercher']], predicted=[allez le chercher]
# src=[['go', 'get', 'it']], target=[['allez', 'le', 'chercher']], predicted=[allez le chercher]
# src=[['go', 'inside']], target=[['entrez']], predicted=[entrez]
# src=[['go', 'to', 'bed']], target=[['va', 'au', 'lit']], predicted=[va au lit]
# src=[['go', 'to', 'bed']], target=[['allez', 'au', 'lit']], predicted=[va au lit]
# src=[['good', 'luck']], target=[['bonne', 'chance']], predicted=[bonne chance]
# src=[['good', 'luck']], target=[['bonne', 'chance']], predicted=[bonne chance]
# src=[['grab', 'that']], target=[['attrape', 'ca']], predicted=[attrape ca]
# src=[['grab', 'that']], target=[['attrapez', 'ca']], predicted=[attrape ca]
# src=[['grab', 'that']], target=[['saisistoi', 'de', 'ca']], predicted=[attrape ca]
# src=[['grab', 'that']], target=[['saisissezvous', 'de', 'ca']], predicted=[attrape ca]
# src=[['grab', 'this']], target=[['attrape', 'ca']], predicted=[attrape ca]
# src=[['grab', 'this']], target=[['attrapez', 'ca']], predicted=[attrape ca]
# src=[['hands', 'off']], target=[['pas', 'touche']], predicted=[joignezvous touche]
# src=[['he', 'is', 'ill']], target=[['il', 'est', 'malade']], predicted=[il est malade]
# src=[['he', 'is', 'old']], target=[['il', 'est', 'vieux']], predicted=[il est vieux]
# src=[['hes', 'good']], target=[['il', 'est', 'bon']], predicted=[il est]
# src=[['hes', 'lazy']], target=[['il', 'est', 'paresseux']], predicted=[il est paresseux]
# src=[['hes', 'rich']], target=[['il', 'est', 'riche']], predicted=[il est riche]
# src=[['here', 'i', 'am']], target=[['me', 'voici']], predicted=[je voici]
# src=[['heres']], target=[['voila', 'cinq', 'dollars']], predicted=[voila cinq dollars]
# src=[['hold', 'fire']], target=[['halte', 'au', 'feu']], predicted=[halte au feu]
# src=[['hold', 'fire']], target=[['cessez', 'le', 'feu']], predicted=[halte au feu]
# src=[['hold', 'this']], target=[['tiens', 'ca']], predicted=[tenez ceci]
# src=[['hold', 'this']], target=[['tenez', 'ca']], predicted=[tenez ceci]
# src=[['hold', 'this']], target=[['tenez', 'ceci']], predicted=[tenez ceci]
# src=[['hold', 'this']], target=[['tiens', 'ceci']], predicted=[tenez ceci]
# src=[['how', 'awful']], target=[['cest', 'affreux']], predicted=[cest affreux]
# src=[['hows', 'tom']], target=[['comment', 'tom', 'vatil']], predicted=[comment a tom]
# src=[['hows', 'tom']], target=[['comment', 'va', 'tom']], predicted=[comment a tom]
# src=[['i', 'am', 'busy']], target=[['je', 'suis', 'occupe']], predicted=[je suis paresseuse]
# src=[['i', 'am', 'calm']], target=[['je', 'suis', 'calme']], predicted=[je suis calme]
# src=[['i', 'am', 'cold']], target=[['jai', 'froid']], predicted=[jai]
# src=[['i', 'am', 'fine']], target=[['je', 'vais', 'bien']], predicted=[je vais bien]
# src=[['i', 'am', 'good']], target=[['je', 'suis', 'bon']], predicted=[je suis]
# src=[['i', 'am', 'here']], target=[['je', 'suis', 'ici']], predicted=[je suis]
# src=[['i', 'am', 'lazy']], target=[['je', 'suis', 'paresseux']], predicted=[je suis paresseuse]
# src=[['i', 'am', 'lazy']], target=[['je', 'suis', 'faineant']], predicted=[je suis paresseuse]
# src=[['i', 'am', 'lazy']], target=[['je', 'suis', 'paresseuse']], predicted=[je suis paresseuse]
# src=[['i', 'am', 'lazy']], target=[['je', 'suis', 'faineante']], predicted=[je suis paresseuse]
# src=[['i', 'am', 'okay']], target=[['je', 'vais', 'bien']], predicted=[je vais bien]
# src=[['i', 'am', 'sick']], target=[['je', 'suis', 'malade']], predicted=[je suis malade]
# src=[['i', 'am', 'sure']], target=[['je', 'suis', 'sur']], predicted=[je suis certain]
# src=[['i', 'am', 'sure']], target=[['je', 'suis', 'certain']], predicted=[je suis certain]
# src=[['i', 'am', 'weak']], target=[['je', 'suis', 'faible']], predicted=[je suis faible]
# src=[['i', 'beg', 'you']], target=[['je', 'vous', 'en', 'prie']], predicted=[je vous en]
# src=[['i', 'beg', 'you']], target=[['je', 'vous', 'en', 'conjure']], predicted=[je vous en]
# src=[['i', 'beg', 'you']], target=[['je', 'vous', 'en', 'supplie']], predicted=[je vous en]
# src=[['i', 'beg', 'you']], target=[['je', 'te', 'prie']], predicted=[je vous en]
# src=[['i', 'can', 'run']], target=[['je', 'sais', 'courir']], predicted=[je sais courir]
# src=[['i', 'can', 'ski']], target=[['je', 'sais', 'skier']], predicted=[je sais courir]
# src=[['i', 'cringed']], target=[['jeus', 'un', 'mouvement', 'de', 'recul']], predicted=[je eu mouvement mouvement recul]
# src=[['i', 'cringed']], target=[['jai', 'eu', 'un', 'mouvement', 'de', 'recul']], predicted=[je eu mouvement mouvement recul]
# src=[['i', 'cringed']], target=[['je', 'suis', 'rentre', 'en', 'moimeme']], predicted=[je eu mouvement mouvement recul]
# src=[['i', 'give', 'up']], target=[['jabandonne']], predicted=[jabandonne]
# src=[['i', 'got', 'hot']], target=[['je', 'me', 'suis', 'mis', 'a', 'avoir', 'chaud']], predicted=[je me suis mis a avoir chaud]
# src=[['i', 'got', 'hot']], target=[['je', 'me', 'suis', 'mise', 'a', 'avoir', 'chaud']], predicted=[je me suis mis a avoir chaud]
# src=[['i', 'had', 'fun']], target=[['je', 'me', 'suis', 'amuse']], predicted=[je me suis marree]
# src=[['i', 'had', 'fun']], target=[['je', 'me', 'suis', 'amusee']], predicted=[je me suis marree]
# src=[['i', 'had', 'fun']], target=[['je', 'me', 'suis', 'marre']], predicted=[je me suis marree]
# src=[['i', 'had', 'fun']], target=[['je', 'me', 'suis', 'marree']], predicted=[je me suis marree]
# src=[['i', 'hate', 'it']], target=[['je', 'deteste', 'ca']], predicted=[je deteste ca]
# src=[['i', 'have', 'it']], target=[['je', 'lai']], predicted=[je lai]
# src=[['i', 'hit', 'tom']], target=[['jai', 'frappe', 'tom']], predicted=[jai frappe tom]
# src=[['i', 'hope', 'so']], target=[['jespere', 'bien']], predicted=[jespere bien]
# src=[['i', 'knew', 'it']], target=[['je', 'le', 'savais']], predicted=[je le]
# src=[['i', 'like', 'it']], target=[['jaime', 'ca']], predicted=[jadore ca]
# src=[['i', 'lost', 'it']], target=[['je', 'lai', 'perdu']], predicted=[je lai]
# src=[['i', 'love', 'it']], target=[['jadore', 'ca']], predicted=[jadore ca]
# src=[['i', 'love', 'it']], target=[['jadore', 'ca']], predicted=[jadore ca]
# src=[['i', 'mean', 'it']], target=[['je', 'suis', 'serieux']], predicted=[je suis serieux]
# src=[['i', 'mean', 'it']], target=[['je', 'suis', 'serieux']], predicted=[je suis serieux]
# src=[['i', 'must', 'go']], target=[['je', 'dois', 'y', 'aller']], predicted=[il me faut]
# src=[['i', 'must', 'go']], target=[['il', 'faut', 'que', 'jy', 'aille']], predicted=[il me faut]
# src=[['i', 'must', 'go']], target=[['il', 'me', 'faut', 'y', 'aller']], predicted=[il me faut]
# src=[['i', 'must', 'go']], target=[['il', 'me', 'faut', 'partir']], predicted=[il me faut]
# src=[['i', 'must', 'go']], target=[['il', 'me', 'faut', 'men', 'aller']], predicted=[il me faut]
# src=[['i', 'must', 'go']], target=[['je', 'dois', 'partir']], predicted=[il me faut]
# src=[['i', 'must', 'go']], target=[['je', 'dois', 'men', 'aller']], predicted=[il me faut]
# src=[['i', 'must', 'go']], target=[['il', 'faut', 'que', 'je', 'men', 'aille']], predicted=[il me faut]
# src=[['i', 'need', 'it']], target=[['jen', 'ai', 'besoin']], predicted=[il me faut]
# src=[['i', 'need', 'it']], target=[['il', 'me', 'le', 'faut']], predicted=[il me faut]
# src=[['i', 'noticed']], target=[['jai', 'remarque']], predicted=[jai remarque]
# src=[['i', 'promise']], target=[['je', 'le', 'promets']], predicted=[je vous promets]
# src=[['i', 'relaxed']], target=[['je', 'me', 'suis', 'detendu']], predicted=[je me suis detendue]
# src=[['i', 'relaxed']], target=[['je', 'me', 'suis', 'detendue']], predicted=[je me suis detendue]
# src=[['i', 'said', 'no']], target=[['jai', 'dit', 'non']], predicted=[jai dit dit]
# src=[['i', 'said', 'so']], target=[['je', 'lai', 'dit']], predicted=[je lai vu]
# src=[['i', 'saw', 'him']], target=[['je', 'lai', 'vu']], predicted=[je lai vu]
# src=[['i', 'saw', 'him']], target=[['je', 'lai', 'vu']], predicted=[je lai vu]
# src=[['i', 'saw', 'him']], target=[['je', 'le', 'vis']], predicted=[je lai vu]
# src=[['i', 'saw', 'one']], target=[['jen', 'ai', 'vu', 'une']], predicted=[jen ai vu une]
# src=[['i', 'saw', 'one']], target=[['jen', 'ai', 'vu', 'un']], predicted=[jen ai vu une]
# src=[['i', 'saw', 'you']], target=[['je', 'vous', 'vis']], predicted=[je vous ai]
# src=[['i', 'saw', 'you']], target=[['je', 'te', 'vis']], predicted=[je vous ai]
# src=[['i', 'saw', 'you']], target=[['je', 'tai', 'vue']], predicted=[je vous ai]
# src=[['i', 'saw', 'you']], target=[['je', 'tai', 'vu']], predicted=[je vous ai]
# src=[['i', 'saw', 'you']], target=[['je', 'vous', 'ai', 'vues']], predicted=[je vous ai]
# src=[['i', 'saw', 'you']], target=[['je', 'vous', 'ai', 'vus']], predicted=[je vous ai]
# src=[['i', 'saw', 'you']], target=[['je', 'vous', 'ai', 'vue']], predicted=[je vous ai]
# src=[['i', 'saw', 'you']], target=[['je', 'vous', 'ai', 'vu']], predicted=[je vous ai]
# src=[['i', 'see', 'tom']], target=[['je', 'vois', 'tom']], predicted=[je vois tom]
# src=[['i', 'shouted']], target=[['jai', 'crie']], predicted=[jai crie]
# src=[['i', 'tripped']], target=[['jai', 'trebuche']], predicted=[jai trebuche]
# src=[['i', 'tripped']], target=[['jai', 'plane']], predicted=[jai trebuche]
# src=[['i', 'want', 'it']], target=[['je', 'le', 'veux']], predicted=[je le]
# src=[['i', 'was', 'new']], target=[['jetais', 'nouveau']], predicted=[jetais nouvelle]
# src=[['i', 'was', 'new']], target=[['jetais', 'nouvelle']], predicted=[jetais nouvelle]
# src=[['i', 'will', 'go']], target=[['jirai']], predicted=[jirai]
# src=[['i', 'woke', 'up']], target=[['je', 'me', 'suis', 'reveille']], predicted=[je me suis]
# src=[['i', 'woke', 'up']], target=[['je', 'me', 'suis', 'eveille']], predicted=[je me suis]
# src=[['id', 'agree']], target=[['je', 'serais', 'daccord']], predicted=[je suis daccord]
# src=[['id', 'leave']], target=[['je', 'partirais']], predicted=[je partirais]
# src=[['ill', 'call']], target=[['jappellerai']], predicted=[jappellerai]
# src=[['ill', 'cook']], target=[['je', 'cuisinerai']], predicted=[je marcherai]
# src=[['ill', 'help']], target=[['jaiderai']], predicted=[jaiderai]
# src=[['ill', 'live']], target=[['je', 'vivrai']], predicted=[je chanterai]
# src=[['ill', 'obey']], target=[['jobeirai']], predicted=[jobeirai]
# src=[['ill', 'pack']], target=[['je', 'ferai', 'mon', 'sac']], predicted=[je ferai ma gaules]
# src=[['ill', 'pack']], target=[['je', 'ferai', 'ma', 'valise']], predicted=[je ferai ma gaules]
# src=[['ill', 'pack']], target=[['je', 'plierai', 'mes', 'gaules']], predicted=[je ferai ma gaules]
# src=[['ill', 'pass']], target=[['je', 'passerai']], predicted=[je nagerai]
# src=[['ill', 'quit']], target=[['jabandonnerai']], predicted=[jabandonnerai]
# src=[['ill', 'sing']], target=[['je', 'chanterai']], predicted=[je chanterai]
# src=[['ill', 'stop']], target=[['jarreterai']], predicted=[jarreterai]
# src=[['ill', 'swim']], target=[['je', 'nagerai']], predicted=[je nagerai]
# src=[['ill', 'talk']], target=[['je', 'parlerai']], predicted=[je vais]
# src=[['ill', 'talk']], target=[['je', 'vais', 'parler']], predicted=[je vais]
# src=[['ill', 'wait']], target=[['jattendrai']], predicted=[jattendrai]
# src=[['ill', 'walk']], target=[['je', 'marcherai']], predicted=[je marcherai]
# ...
# src=[['im', 'drunk']], target=[['je', 'suis', 'ivre']], predicted=[je suis gras]
# src=[['im', 'dying']], target=[['je', 'me', 'meurs']], predicted=[je suis en]
# src=[['im', 'early']], target=[['je', 'suis', 'en', 'avance']], predicted=[je suis en]
# src=[['im', 'first']], target=[['je', 'suis', 'en', 'premier']], predicted=[je suis en]
# src=[['im', 'fussy']], target=[['je', 'suis', 'difficile']], predicted=[je suis libre]
# src=[['im', 'fussy']], target=[['je', 'suis', 'tatillon']], predicted=[je suis libre]
# src=[['im', 'fussy']], target=[['je', 'suis', 'tatillonne']], predicted=[je suis libre]
# src=[['im', 'going']], target=[['je', 'pars', 'maintenant']], predicted=[je vais]
# src=[['im', 'going']], target=[['je', 'me', 'tire']], predicted=[je vais]
# src=[['im', 'going']], target=[['jy', 'vais']], predicted=[je vais]
# src=[['im', 'going']], target=[['je', 'pars']], predicted=[je vais]
# src=[['im', 'loyal']], target=[['je', 'suis', 'loyal']], predicted=[je suis faible]
# src=[['im', 'loyal']], target=[['je', 'suis', 'loyale']], predicted=[je suis faible]
# src=[['im', 'lucky']], target=[['je', 'suis', 'veinard']], predicted=[je suis]
# src=[['im', 'lucky']], target=[['je', 'suis', 'veinarde']], predicted=[je suis]
# src=[['im', 'lucky']], target=[['jai', 'du', 'pot']], predicted=[je suis]
# src=[['im', 'lucky']], target=[['je', 'suis', 'chanceux']], predicted=[je suis]
# src=[['im', 'lucky']], target=[['je', 'suis', 'chanceuse']], predicted=[je suis]
# src=[['im', 'lying']], target=[['je', 'suis', 'en', 'train', 'de', 'mentir']], predicted=[je suis en train de mentir]
# src=[['im', 'quiet']], target=[['je', 'suis', 'tranquille']], predicted=[je suis tranquille]
# src=[['im', 'ready']], target=[['je', 'suis', 'prete']], predicted=[je suis pret]
# src=[['im', 'ready']], target=[['je', 'suis', 'pret']], predicted=[je suis pret]
# src=[['im', 'ready']], target=[['je', 'suis', 'pret']], predicted=[je suis pret]
# src=[['im', 'right']], target=[['jai', 'raison']], predicted=[jai raison]
# src=[['im', 'sober']], target=[['je', 'suis', 'sobre']], predicted=[je suis pret]
# src=[['im', 'sorry']], target=[['excusemoi']], predicted=[desole]
# src=[['im', 'sorry']], target=[['desole']], predicted=[desole]
# src=[['im', 'sorry']], target=[['desole']], predicted=[desole]
# src=[['im', 'sorry']], target=[['je', 'suis', 'desole']], predicted=[desole]
# src=[['im', 'sorry']], target=[['je', 'suis', 'desolee']], predicted=[desole]
# src=[['im', 'stuck']], target=[['je', 'suis', 'coincee']], predicted=[je suis pret]
# src=[['im', 'timid']], target=[['je', 'suis', 'timide']], predicted=[je suis timide]
# src=[['im', 'tired']], target=[['je', 'suis', 'fatigue']], predicted=[je suis timide]
# src=[['im', 'tough']], target=[['je', 'suis', 'dur']], predicted=[je suis dur]
# src=[['im', 'tough']], target=[['je', 'suis', 'dure']], predicted=[je suis dur]
# src=[['im', 'tough']], target=[['je', 'suis', 'dur', 'a', 'cuire']], predicted=[je suis dur]
# src=[['im', 'tough']], target=[['je', 'suis', 'dure', 'a', 'cuire']], predicted=[je suis dur]
# src=[['im', 'yours']], target=[['je', 'suis', 'a', 'toi']], predicted=[je suis a]
# src=[['im', 'yours']], target=[['je', 'suis', 'a', 'vous']], predicted=[je suis a]
# src=[['ive', 'lost']], target=[['jai', 'perdu']], predicted=[jai perdu]
# src=[['is', 'tom', 'ok']], target=[['estce', 'que', 'tom', 'va', 'bien']], predicted=[estce vatil tom]
# src=[['is', 'tom', 'ok']], target=[['tom', 'vatil', 'bien']], predicted=[estce vatil tom]
# src=[['is', 'it', 'bad']], target=[['cest', 'grave']], predicted=[cest grave]
# src=[['is', 'it', 'far']], target=[['estce', 'eloigne']], predicted=[estce loin]
# src=[['is', 'it', 'far']], target=[['estce', 'loin']], predicted=[estce loin]
# src=[['is', 'it', 'hot']], target=[['estce', 'chaud']], predicted=[estce chaud]
# src=[['is', 'it', 'you']], target=[['estce', 'toi']], predicted=[estce toi]
# src=[['is', 'it', 'you']], target=[['estce', 'vous']], predicted=[estce toi]
# src=[['is', 'it', 'you']], target=[['estce', 'que', 'cest', 'vous']], predicted=[estce toi]
# src=[['it', 'failed']], target=[['ca', 'a', 'echoue']], predicted=[ca a echoue]
# src=[['it', 'is', 'new']], target=[['cest', 'nouveau']], predicted=[cest neuf]
# src=[['it', 'is', 'new']], target=[['cest', 'neuf']], predicted=[cest neuf]
# src=[['it', 'snowed']], target=[['il', 'a', 'neige']], predicted=[il a neige]
# src=[['it', 'stinks']], target=[['ca', 'sent', 'mauvais']], predicted=[ca pue]
# src=[['it', 'stinks']], target=[['ca', 'pue']], predicted=[ca pue]
# src=[['it', 'worked']], target=[['ca', 'a', 'fonctionne']], predicted=[ca a marche]
# src=[['it', 'worked']], target=[['ca', 'a', 'marche']], predicted=[ca a marche]
# src=[['its']], target=[['il', 'est', 'trois', 'heures', 'et', 'demie']], predicted=[qui est]
# src=[['its']], target=[['il', 'est', 'huit', 'heures', 'trente']], predicted=[qui est]
# src=[['its']], target=[['il', 'est']], predicted=[qui est]
# src=[['its', 'cold']], target=[['il', 'fait', 'froid']], predicted=[cest froid]
# src=[['its', 'cold']], target=[['cest', 'froid']], predicted=[cest froid]
# src=[['its', 'dark']], target=[['cest', 'sombre']], predicted=[cest neuf]
# src=[['its', 'dead']], target=[['elle', 'est', 'morte']], predicted=[elle est]
# src=[['its', 'dead']], target=[['cest', 'mort']], predicted=[elle est]
# src=[['its', 'dead']], target=[['il', 'est', 'mort']], predicted=[elle est]
# src=[['its', 'done']], target=[['cest', 'fait']], predicted=[cest fait]
# src=[['its', 'food']], target=[['cest', 'de', 'la', 'nourriture']], predicted=[cest sommes daccord nourriture]
# src=[['its', 'free']], target=[['cest', 'gratuit']], predicted=[cest gratuit]
# src=[['its', 'here']], target=[['elle', 'est', 'ici']], predicted=[elle ici]
# src=[['its', 'here']], target=[['cest', 'ici']], predicted=[elle ici]
# src=[['its', 'hers']], target=[['cest', 'le', 'sien']], predicted=[cest est]
# src=[['its', 'hers']], target=[['cest', 'la', 'sienne']], predicted=[cest est]
# src=[['its', 'late']], target=[['il', 'est', 'tard']], predicted=[il est mort]
# src=[['its', 'lost']], target=[['cest', 'perdu']], predicted=[cest rigolo]
# src=[['its', 'open']], target=[['cest', 'ouvert']], predicted=[cest neuf]
# src=[['its', 'ours']], target=[['cest', 'le', 'notre']], predicted=[cest la notre]
# src=[['its', 'ours']], target=[['cest', 'la', 'notre']], predicted=[cest la notre]
# src=[['its', 'ours']], target=[['cest', 'a', 'nous']], predicted=[cest la notre]
# src=[['its', 'sand']], target=[['cest', 'du', 'sable']], predicted=[cest du sable]
# src=[['its', 'time']], target=[['il', 'est', 'temps']], predicted=[il est]
# src=[['its', 'time']], target=[['cest', 'lheure']], predicted=[il est]
# src=[['its', 'true']], target=[['cest', 'vrai']], predicted=[cest vrai]
# src=[['its', 'work']], target=[['cest', 'du', 'boulot']], predicted=[cest est]
# src=[['keep', 'this']], target=[['garde', 'ca']], predicted=[gardez ceci]
# src=[['keep', 'this']], target=[['gardez', 'ceci']], predicted=[gardez ceci]
# src=[['let', 'it', 'be']], target=[['ainsi', 'soitil']], predicted=[ainsi soitil]
# src=[['let', 'it', 'be']], target=[['laisse', 'faire']], predicted=[ainsi soitil]
# src=[['let', 'me', 'go']], target=[['laissemoi', 'partir']], predicted=[laissemoi men]
# src=[['let', 'me', 'go']], target=[['laissezmoi', 'partir']], predicted=[laissemoi men]
# src=[['let', 'me', 'go']], target=[['lachemoi']], predicted=[laissemoi men]
# src=[['let', 'me', 'go']], target=[['lachezmoi']], predicted=[laissemoi men]
# src=[['let', 'me', 'go']], target=[['laissemoi', 'men', 'aller']], predicted=[laissemoi men]
# src=[['let', 'me', 'go']], target=[['laissezmoi', 'men', 'aller']], predicted=[laissemoi men]
# src=[['let', 'me', 'go']], target=[['laissezmoi', 'y', 'aller']], predicted=[laissemoi men]
# src=[['let', 'me', 'go']], target=[['laissemoi', 'y', 'aller']], predicted=[laissemoi men]
# src=[['let', 'me', 'go']], target=[['laissemoi', 'partir']], predicted=[laissemoi men]
# src=[['let', 'me', 'go']], target=[['laissezmoi', 'partir']], predicted=[laissemoi men]
# src=[['let', 'me', 'go']], target=[['laissemoi', 'men', 'aller']], predicted=[laissemoi men]
# src=[['let', 'me', 'go']], target=[['laissezmoi', 'men', 'aller']], predicted=[laissemoi men]
# src=[['let', 'me', 'in']], target=[['laissezmoi', 'rentrer']], predicted=[laissezmoi rentrer]
# src=[['let', 'me', 'in']], target=[['laissezmoi', 'entrer']], predicted=[laissezmoi rentrer]
# src=[['lets', 'ask']], target=[['demandons']], predicted=[demandons]
# src=[['lets', 'see']], target=[['voyons', 'voir']], predicted=[voyons voir]
# src=[['lie', 'still']], target=[['reste', 'allonge', 'immobile']], predicted=[restez allongee immobile]
# src=[['lie', 'still']], target=[['reste', 'allongee', 'immobile']], predicted=[restez allongee immobile]
# src=[['lie', 'still']], target=[['restez', 'allonge', 'immobile']], predicted=[restez allongee immobile]
# src=[['lie', 'still']], target=[['restez', 'allongee', 'immobile']], predicted=[restez allongee immobile]
# src=[['lie', 'still']], target=[['restez', 'allonges', 'immobiles']], predicted=[restez allongee immobile]
# src=[['lie', 'still']], target=[['restez', 'allongees', 'immobiles']], predicted=[restez allongee immobile]
# src=[['look', 'back']], target=[['regarde', 'derriere', 'toi']], predicted=[regarde derriere]
# src=[['look', 'back']], target=[['regarde', 'derriere']], predicted=[regarde derriere]
# src=[['look', 'here']], target=[['regarde', 'ici']], predicted=[restez ici]
# src=[['look', 'here']], target=[['regardez', 'ici']], predicted=[restez ici]
# src=[['loosen', 'up']], target=[['echauffetoi']], predicted=[echauffetoi]
# src=[['loosen', 'up']], target=[['echauffezvous']], predicted=[echauffetoi]
# src=[['loosen', 'up']], target=[['detendstoi']], predicted=[echauffetoi]
# src=[['loosen', 'up']], target=[['laissetoi', 'aller']], predicted=[echauffetoi]
# src=[['loosen', 'up']], target=[['laissezvous', 'aller']], predicted=[echauffetoi]
# src=[['move', 'over']], target=[['bouge', 'de', 'la']], predicted=[poussetoi]
# src=[['move', 'over']], target=[['poussezvous']], predicted=[poussetoi]
# src=[['move', 'over']], target=[['poussetoi']], predicted=[poussetoi]
# src=[['nice', 'shot']], target=[['joli', 'coup']], predicted=[joli coup]
# src=[['of', 'course']], target=[['pour', 'sur']], predicted=[pour sur]
# src=[['of', 'course']], target=[['mais', 'ouais']], predicted=[pour sur]
# src=[['of', 'course']], target=[['pardi']], predicted=[pour sur]
# src=[['of', 'course']], target=[['bien', 'sur']], predicted=[pour sur]
# src=[['of', 'course']], target=[['pour', 'sur']], predicted=[pour sur]
# src=[['oh', 'please']], target=[['je', 'vous', 'en', 'prie']], predicted=[je vous prie]
# src=[['oh', 'please']], target=[['je', 'ten', 'prie']], predicted=[je vous prie]
# src=[['pardon', 'me']], target=[['pardon']], predicted=[plaitil]
# src=[['pardon', 'me']], target=[['je', 'vous', 'demande', 'pardon']], predicted=[plaitil]
# src=[['pardon', 'me']], target=[['plaitil']], predicted=[plaitil]
# src=[['read', 'this']], target=[['lis', 'ceci']], predicted=[lis ceci]
# src=[['say', 'hello']], target=[['dis', 'bonjour']], predicted=[dis bonjour]
# src=[['see', 'above']], target=[['voyez', 'cidessus']], predicted=[voyez cidessus]
# src=[['see', 'below']], target=[['voyez', 'cidessous']], predicted=[voyez cidessous]
# src=[['see', 'below']], target=[['voir', 'cidessous']], predicted=[voyez cidessous]
# src=[['seriously']], target=[['vraiment']], predicted=[vraiment]
# src=[['seriously']], target=[['estce', 'serieux']], predicted=[vraiment]
# src=[['seriously']], target=[['serieusement']], predicted=[vraiment]
# src=[['she', 'cried']], target=[['elle', 'pleurait']], predicted=[elle crie]
# src=[['she', 'cried']], target=[['elle', 'pleura']], predicted=[elle crie]
# src=[['she', 'cried']], target=[['elle', 'crie']], predicted=[elle crie]
# src=[['she', 'tried']], target=[['elle', 'a', 'essaye']], predicted=[restez a essaye]
# src=[['she', 'walks']], target=[['elle', 'marche']], predicted=[elle marche]
# src=[['shes', 'hot']], target=[['elle', 'est', 'chaude']], predicted=[elle est tres]
# src=[['shes', 'hot']], target=[['elle', 'est', 'tres', 'attirante']], predicted=[elle est tres]
# src=[['sign', 'here']], target=[['signe', 'ici']], predicted=[signe ici]
# src=[['sign', 'here']], target=[['signez', 'ici']], predicted=[signe ici]
# src=[['sign', 'this']], target=[['signe', 'ca']], predicted=[signez ceci]
# src=[['sign', 'this']], target=[['signez', 'ceci']], predicted=[signez ceci]
# src=[['slow', 'down']], target=[['ralentis']], predicted=[calmezvous]
# src=[['slow', 'down']], target=[['ralentissez']], predicted=[calmezvous]
# src=[['stay', 'back']], target=[['reste', 'en', 'arriere']], predicted=[reste en arriere]
# src=[['stay', 'back']], target=[['restez', 'en', 'arriere']], predicted=[reste en arriere]
# src=[['stay', 'calm']], target=[['restez', 'calme']], predicted=[reste calme]
# src=[['stay', 'calm']], target=[['reste', 'calme']], predicted=[reste calme]
# src=[['stay', 'calm']], target=[['garde', 'ton', 'calme']], predicted=[reste calme]
# src=[['stay', 'calm']], target=[['garde', 'ton', 'sangfroid']], predicted=[reste calme]
# src=[['stay', 'calm']], target=[['reste', 'tranquille']], predicted=[reste calme]
# src=[['stay', 'down']], target=[['reste', 'baisse']], predicted=[reste baisse]
# src=[['stay', 'down']], target=[['restez', 'baisse']], predicted=[reste baisse]
# src=[['stay', 'down']], target=[['reste', 'baisse']], predicted=[reste baisse]
# src=[['stay', 'down']], target=[['restez', 'baisse']], predicted=[reste baisse]
# src=[['stay', 'here']], target=[['restez', 'la']], predicted=[reste ici]
# src=[['stay', 'here']], target=[['reste', 'ici']], predicted=[reste ici]
# src=[['stay', 'here']], target=[['restez', 'ici']], predicted=[reste ici]
# src=[['stay', 'thin']], target=[['reste', 'mince']], predicted=[reste mince]
# src=[['step', 'back']], target=[['recule']], predicted=[reculez]
# src=[['step', 'back']], target=[['reculez']], predicted=[reculez]
# src=[['stop', 'that']], target=[['arretez']], predicted=[arretez ca]
# src=[['stop', 'that']], target=[['arretez', 'ca']], predicted=[arretez ca]
# src=[['stop', 'that']], target=[['arrete', 'ca']], predicted=[arretez ca]
# src=[['stop', 'them']], target=[['arretezles']], predicted=[arretezles]
# src=[['take', 'care']], target=[['prends', 'soin', 'de', 'toi']], predicted=[prends soin de toi]
# src=[['take', 'care']], target=[['soyez', 'prudente']], predicted=[prends soin de toi]
# src=[['take', 'care']], target=[['prends', 'soin', 'de', 'toi']], predicted=[prends soin de toi]
# src=[['take', 'care']], target=[['prenez', 'soin', 'de', 'vous']], predicted=[prends soin de toi]
# src=[['take', 'mine']], target=[['prends', 'le', 'mien']], predicted=[prenez les miens]
# src=[['take', 'mine']], target=[['prends', 'la', 'mienne']], predicted=[prenez les miens]
# src=[['take', 'mine']], target=[['prenez', 'le', 'mien']], predicted=[prenez les miens]
# src=[['take', 'mine']], target=[['prenez', 'la', 'mienne']], predicted=[prenez les miens]
# src=[['take', 'mine']], target=[['prends', 'les', 'miens']], predicted=[prenez les miens]
# src=[['take', 'mine']], target=[['prends', 'les', 'miennes']], predicted=[prenez les miens]
# src=[['take', 'mine']], target=[['prenez', 'les', 'miens']], predicted=[prenez les miens]
# src=[['take', 'mine']], target=[['prenez', 'les', 'miennes']], predicted=[prenez les miens]
# src=[['take', 'this']], target=[['prends', 'ca']], predicted=[prends ca]
# src=[['take', 'this']], target=[['prenez', 'ca']], predicted=[prends ca]
# src=[['thank', 'you']], target=[['merci']], predicted=[merci]
# src=[['thats', 'it']], target=[['cest', 'ca']], predicted=[cest a]
# src=[['they', 'fell']], target=[['ils', 'sont', 'tombes']], predicted=[ils sont tombees]
# src=[['they', 'fell']], target=[['elles', 'sont', 'tombees']], predicted=[ils sont tombees]
# src=[['they', 'left']], target=[['ils', 'sont', 'partis']], predicted=[ils sont partis]
# src=[['they', 'left']], target=[['elles', 'sont', 'parties']], predicted=[ils sont partis]
# src=[['they', 'lied']], target=[['ils', 'ont', 'menti']], predicted=[ils ont menti]
# src=[['they', 'lied']], target=[['elles', 'ont', 'menti']], predicted=[ils ont menti]
